# %%
import json
import pandas as pd


data = []
with open("/home/ssn899/Desktop/P2P_LLM/Distributed-Inference-for-Edge-LLMs/runs/sglang_run_20260417_021034/debug.jsonl","r") as f:
    for line in f:
        data.append(json.loads(line))

# %%
len(data)
# Out:
# 13757

# %%
data[0]
# Out:
# {'request_id': 0,
#  'subject': 'professional_law',
#  'target_node': 0,
#  'ingress_node': 0,
#  'selected_node': 0,
#  'processed_by': 0,
#  'routed_from': None,
#  'routed_to': None,
#  'prefix_match_input_tokens': 1359,
#  'sglang_prompt_tokens': 1359,
#  'sglang_cache_hit_tokens': 0,
#  'sglang_cache_hit_ratio': 0.0,
#  'per_node_expected_cache_hits': [{'node_id': 0,
#    'expected_cache_hit_tokens': 0,
#    'was_selected': True},
#   {'node_id': 1, 'expected_cache_hit_tokens': 0, 'was_selected': False},
#   {'node_id': 2, 'expected_cache_hit_tokens': 0, 'was_selected': False},
#   {'node_id': 3, 'expected_cache_hit_tokens': 0, 'was_selected': False}],
#  'local_snapshot_match_after_process': 1359}

# %%
data_ele = {}
for ele in data:
    if ele['subject']=="elementary_mathematics":
        data_ele[ele['request_id']] = ele

# %%
data_ele[3545]
# Out:
# {'request_id': 3545,
#  'subject': 'elementary_mathematics',
#  'target_node': 0,
#  'ingress_node': 0,
#  'selected_node': 1,
#  'processed_by': 1,
#  'routed_from': 0,
#  'routed_to': 1,
#  'prefix_match_input_tokens': 395,
#  'sglang_prompt_tokens': 395,
#  'sglang_cache_hit_tokens': 320,
#  'sglang_cache_hit_ratio': 0.8101,
#  'per_node_expected_cache_hits': [{'node_id': 0,
#    'expected_cache_hit_tokens': 0,
#    'was_selected': False},
#   {'node_id': 1, 'expected_cache_hit_tokens': 320, 'was_selected': True},
#   {'node_id': 2, 'expected_cache_hit_tokens': 3, 'was_selected': False},
#   {'node_id': 3, 'expected_cache_hit_tokens': 0, 'was_selected': False}],
#  'local_snapshot_match_after_process': 320}

# %%
data_ele[3586]
# Out:
# {'request_id': 3586,
#  'subject': 'elementary_mathematics',
#  'target_node': 1,
#  'ingress_node': 1,
#  'selected_node': 2,
#  'processed_by': 2,
#  'routed_from': 1,
#  'routed_to': 2,
#  'prefix_match_input_tokens': 359,
#  'sglang_prompt_tokens': 359,
#  'sglang_cache_hit_tokens': 3,
#  'sglang_cache_hit_ratio': 0.0084,
#  'per_node_expected_cache_hits': [{'node_id': 0,
#    'expected_cache_hit_tokens': 0,
#    'was_selected': False},
#   {'node_id': 1, 'expected_cache_hit_tokens': 1, 'was_selected': False},
#   {'node_id': 2, 'expected_cache_hit_tokens': 3, 'was_selected': True},
#   {'node_id': 3, 'expected_cache_hit_tokens': 0, 'was_selected': False}],
#  'local_snapshot_match_after_process': 359}

# %%
data_ele[3605]
# Out:
# {'request_id': 3605,
#  'subject': 'elementary_mathematics',
#  'target_node': 0,
#  'ingress_node': 0,
#  'selected_node': 1,
#  'processed_by': 1,
#  'routed_from': 0,
#  'routed_to': 1,
#  'prefix_match_input_tokens': 389,
#  'sglang_prompt_tokens': 389,
#  'sglang_cache_hit_tokens': 321,
#  'sglang_cache_hit_ratio': 0.8252,
#  'per_node_expected_cache_hits': [{'node_id': 0,
#    'expected_cache_hit_tokens': 0,
#    'was_selected': False},
#   {'node_id': 1, 'expected_cache_hit_tokens': 321, 'was_selected': True},
#   {'node_id': 2, 'expected_cache_hit_tokens': 3, 'was_selected': False},
#   {'node_id': 3, 'expected_cache_hit_tokens': 0, 'was_selected': False}],
#  'local_snapshot_match_after_process': 1}

# %%
data_ele[3619]
# Out:
# {'request_id': 3619,
#  'subject': 'elementary_mathematics',
#  'target_node': 2,
#  'ingress_node': 2,
#  'selected_node': 1,
#  'processed_by': 1,
#  'routed_from': 2,
#  'routed_to': 1,
#  'prefix_match_input_tokens': 382,
#  'sglang_prompt_tokens': 382,
#  'sglang_cache_hit_tokens': 321,
#  'sglang_cache_hit_ratio': 0.8403,
#  'per_node_expected_cache_hits': [{'node_id': 0,
#    'expected_cache_hit_tokens': 0,
#    'was_selected': False},
#   {'node_id': 1, 'expected_cache_hit_tokens': 321, 'was_selected': True},
#   {'node_id': 2, 'expected_cache_hit_tokens': 320, 'was_selected': False},
#   {'node_id': 3, 'expected_cache_hit_tokens': 0, 'was_selected': False}],
#  'local_snapshot_match_after_process': 1}

# %%
df = pd.read_csv("/home/ssn899/Desktop/P2P_LLM/Distributed-Inference-for-Edge-LLMs/runs/sglang_run_20260417_021034/results.csv",sep="|")

# %%
df['total_time_s'].sum()/len(df)
# Out:
# np.float64(1.0893149741949553)

# %%
import pandas as pd
import json

x = []
with open("/home/ssn899/Desktop/P2P_LLM/Distributed-Inference-for-Edge-LLMs/runs/comm_2ms_gpu0.1_n4/debug.jsonl","r") as f:
    for ele in f:
        x.append(json.loads(ele))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[1], line 7
#       5 with open("/home/ssn899/Desktop/P2P_LLM/Distributed-Inference-for-Edge-LLMs/runs/comm_2ms_gpu0.1_n4/debug.jsonl","r") as f:
#       6     for ele in f:
# ----> 7         x.append(json.loads(ele))
#
# File ~/miniforge3/envs/dist2/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...

# %%
df = pd.read_csv("/home/ssn899/Desktop/P2P_LLM/Distributed-Inference-for-Edge-LLMs/runs/sglang_comm50ms_poll2_gpu0.1.yaml/results.csv",sep="|")

# %%
df
# Out:
#       request_id                  subject  target_node  ingress_node  \
# 0              0         professional_law            0             0
# 1              1  professional_psychology            1             1
# 2              2            miscellaneous            2             2
# 3              3              human_aging            3             3
# 4              4                  anatomy            0             0
# ...          ...                      ...          ...           ...
# 8633        8633             formal_logic            0             0
# 8634        8634      high_school_physics            1             1
# 8635        8635          moral_scenarios            2             2
# 8636        8636          moral_scenarios            3             3
# 8637        8637        college_chemistry            0             0
#
#       processed_by  routed_from  routed_to  prefix_match_input_tokens  \
# ...
