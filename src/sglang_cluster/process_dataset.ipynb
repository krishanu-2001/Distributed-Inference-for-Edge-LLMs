# %%
import pandas as pd

df = pd.read_csv("/home/ssn899/Desktop/P2P_LLM/Distributed-Inference-for-Edge-LLMs/datasets/requests.csv")

# %%
df_law = df[df['subject']=="professional_law"]

# %%
df_law = df_law[:200]
df_law.reset_index(inplace=True,drop=True)

# %%
for idx,ele in df_law.iterrows():
    if idx < 100:
        df_law.loc[idx, "target_node"] = 0
    else:
        df_law.loc[idx, "target_node"] = 1

# %%
df_law
# Out:
#                                                   text  target_node  \
# 0    One afternoon, a pilot was flying a small airp...            0
# 1    One afternoon, a pilot was flying a small airp...            0
# 2    One afternoon, a pilot was flying a small airp...            0
# 3    One afternoon, a pilot was flying a small airp...            0
# 4    One afternoon, a pilot was flying a small airp...            0
# ..                                                 ...          ...
# 195  One afternoon, a pilot was flying a small airp...            1
# 196  One afternoon, a pilot was flying a small airp...            1
# 197  One afternoon, a pilot was flying a small airp...            1
# 198  One afternoon, a pilot was flying a small airp...            1
# 199  One afternoon, a pilot was flying a small airp...            1
#
#               subject
# 0    professional_law
# 1    professional_law
# 2    professional_law
# 3    professional_law
# 4    professional_law
# ...

# %%
df_law.to_csv("/home/ssn899/Desktop/P2P_LLM/Distributed-Inference-for-Edge-LLMs/datasets/requests_law_test_200.csv")

# %%
df = df[:5]
df.to_csv("/home/ssn899/Desktop/P2P_LLM/Distributed-Inference-for-Edge-LLMs/datasets/requests_5.csv")

# %%
import pandas as pd
import json
results = pd.read_csv("/home/ssn899/Desktop/P2P_LLM/Distributed-Inference-for-Edge-LLMs/runs/sglang_run_20260416_223418/results.csv",sep="|")
debug_data = []
with open("/home/ssn899/Desktop/P2P_LLM/Distributed-Inference-for-Edge-LLMs/runs/sglang_run_20260416_223418/debug.jsonl","r", encoding='utf-8') as f:
    for line in f:
        # print(line)
        debug_data.append(json.loads(line))

# %%
for ele in debug_data[0:10]:
    print(ele)
# Out:
# {'request_id': 0, 'subject': 'professional_law', 'target_node': 0, 'ingress_node': 0, 'selected_node': 0, 'processed_by': 0, 'routed_from': None, 'routed_to': None, 'prefix_match_input_tokens': 1359, 'sglang_prompt_tokens': 1359, 'sglang_cache_hit_tokens': 0, 'sglang_cache_hit_ratio': 0.0, 'per_node_expected_cache_hits': [{'node_id': 0, 'expected_cache_hit_tokens': 0, 'was_selected': True}, {'node_id': 1, 'expected_cache_hit_tokens': 0, 'was_selected': False}, {'node_id': 2, 'expected_cache_hit_tokens': 0, 'was_selected': False}, {'node_id': 3, 'expected_cache_hit_tokens': 0, 'was_selected': False}], 'local_snapshot_match_after_process': 1359}
# ...

# %%
results
# Out:
#      request_id           subject  target_node  ingress_node  processed_by  \
# 0             0  professional_law            0             0             0
# 1             1  professional_law            0             0             0
# 2             2  professional_law            0             0             0
# 3             3  professional_law            0             0             0
# 4             4  professional_law            0             0             0
# ..          ...               ...          ...           ...           ...
# 195         195  professional_law            1             1             0
# 196         196  professional_law            1             1             0
# 197         197  professional_law            1             1             0
# 198         198  professional_law            1             1             0
# 199         199  professional_law            1             1             0
#
#      routed_from  routed_to  prefix_match_input_tokens  \
# ...

# %%
import pandas as pd
df_law = pd.read_csv("/home/ssn899/Desktop/P2P_LLM/Distributed-Inference-for-Edge-LLMs/datasets/requests_law_200.csv")

# %%
df_law['text'][0]
# Out:
# 'One afternoon, a pilot was flying a small airplane when it suddenly ran out of gas. As he was coming in for an emergency landing, the plane crossed into a neighboring state at a very low altitude. At this time, a 9-year-old boy was walking to school when he was struck and injured by an object, which may have fallen from the plane. In federal court, a negligence suit was brought against the pilot by the father of the boy for his son. Accompanied by his father, the boy had visited an attorney for preliminary discussions regarding the case. However, the father did not retain the attorney to represent his son in the lawsuit. Instead, the father hired another lawyer to handle the case. At trial, the pilot\'s attorney calls the consulting attorney to testify what the boy had said to him regarding his physical condition during the consultation that the attorney had had with the boy and his father. The attorney\'s testimony is\nA. admissible, because the attorney-client privilege was waived
# ...

# %%
df_law['text'][1]
# Out:
# 'One afternoon, a pilot was flying a small airplane when it suddenly ran out of gas. As he was coming in for an emergency landing, the plane crossed into a neighboring state at a very low altitude. At this time, a 9-year-old boy was walking to school when he was struck and injured by an object, which may have fallen from the plane. In federal court, a negligence suit was brought against the pilot by the father of the boy for his son. Accompanied by his father, the boy had visited an attorney for preliminary discussions regarding the case. However, the father did not retain the attorney to represent his son in the lawsuit. Instead, the father hired another lawyer to handle the case. At trial, the pilot\'s attorney calls the consulting attorney to testify what the boy had said to him regarding his physical condition during the consultation that the attorney had had with the boy and his father. The attorney\'s testimony is\nA. admissible, because the attorney-client privilege was waived
# ...

# %%
for i in range(len(results)):
